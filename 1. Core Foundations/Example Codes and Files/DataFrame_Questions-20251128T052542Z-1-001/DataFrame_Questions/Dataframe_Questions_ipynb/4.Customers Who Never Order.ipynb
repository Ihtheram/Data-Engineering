# %% [markdown]
# **Question:**
#
# Write a solution to find all customers who never order anything.
# Return the result table in any order.

# %% [markdown]
# **Sample Input**
#
#
# Customers Table
#
#
# ```
# 	id	name
# 0	1	Joe
# 1	2	Henry
# 2	3	Sam
# 3	4	Max
# ```
#
#
# Orders Table
#
#
#
# ```
# 	id	customerID
# 0	1	3
# 1	2	1
#
# ```
# **Sample Output**
#
#
#
# ```
#   Customers
# 0     Henry
# 1       Max
# ```

# %% [markdown]
# **Your Answer Here**

# %% [markdown]
# **Expected Output**
#
#
# ```
#  Customers
# 1       Bob
# 4       Eve
# ```
