# %% [markdown]
# **Question:**
#
# Write a solution to find the users who have valid emails.
#
# A valid e-mail has a prefix name and a domain where:
#
#
# *   The prefix name is a string that may contain letters (upper or lower case), digits, underscore '_', period '.', and/or dash '-'. The prefix name must start with a letter.
# *   The domain is '@dataengineeracademy.com'.
#
# Return the result table in any order.

# %% [markdown]
# **Sample Input:**
#
# Users table:
#
#
# ```
#    user_id       name                     mail
# 0        1    Winston     winston@leetcode.com
# 1        2   Jonathan          jonathanisgreat
# 2        3  Annabelle      bella-@leetcode.com
# 3        4      Sally  sally.come@leetcode.com
# 4        5     Marwan  quarz#2020@leetcode.com
# 5        6      David        david69@gmail.com
# 6        7    Shapiro      .shapo@leetcode.com
# ```
#
#
#
# **Sample Output:**
#
#
# ```
#    user_id       name                     mail
# 0        1    Winston     winston@leetcode.com
# 1        3  Annabelle      bella-@leetcode.com
# 2        4      Sally  sally.come@leetcode.com
#
# ```

# %% [markdown]
# **Explanation:**
#
# The mail of user 2 does not have a domain.
#
# The mail of user 5 has the # sign which is not allowed.
#
# The mail of user 6 does not have the leetcode domain.
#
# The mail of user 7 starts with a period.

# %% [markdown]
# **Your Answer Here**

# %% [markdown]
# **Expected Output**
#
#
#
# ```
#    user_id       name                                mail
# 0        1    Winston     winston@dataengineeracademy.com
# 2        3  Annabelle      bella-@dataengineeracademy.com
# 3        4      Sally  sally.come@dataengineeracademy.com
# ```
