# %% [markdown]
# **Question:**
#
# For each date_id and make_name, find the number of distinct lead_id's and distinct partner_id's.
#
# Return the result table in any order.

# %% [markdown]
# **Sample Input:**
#
# DailySales table:
#
#
# ```
#     date_id   make_name   lead_id   partner_id
# 0  2020-12-8    toyota        0           1
# 1  2020-12-8    toyota        1           0
# 2  2020-12-8    toyota        1           2
# 3  2020-12-7    toyota        0           2
# 4  2020-12-7    toyota        0           1
# 5  2020-12-8     honda        1           2
# 6  2020-12-8     honda        2           1
# 7  2020-12-7     honda        0           1
# 8  2020-12-7     honda        1           2
# 9  2020-12-7     honda        2           1
# ```
#
#
# **Sample Output:**
#
#
# ```
#     date_id   make_name   unique_leads   unique_partners
# 0  2020-12-8    toyota             2                3
# 1  2020-12-7    toyota             1                2
# 2  2020-12-8     honda             2                2
# 3  2020-12-7     honda             3                2
# ```

# %% [markdown]
# **Explanation:**
#
# For 2020-12-8, toyota gets leads = [0, 1] and partners = [0, 1, 2] while honda gets leads = [1, 2] and partners = [1, 2].
#
# For 2020-12-7, toyota gets leads = [0] and partners = [1, 2] while honda gets leads = [0, 1, 2] and partners = [1, 2].

# %% [markdown]
# **Your Answer Here**

# %% [markdown]
# **Expected output**
#
#
#
# ```
#      date_id make_name  unique_leads  unique_partners
# 0  2024-01-01      ford             1                1
# 1  2024-01-01    toyota             2                3
# 2  2024-01-02      ford             1                1
# 3  2024-01-02    toyota             1                2
# 4  2024-01-03      ford             1                1
# 5  2024-01-03     honda             2                2
# 6  2024-01-04      ford             1                1
# 7  2024-01-04     honda             2                2
# 8  2024-01-05      ford             1                1
# 9  2024-01-05     honda             1                1
# ```
