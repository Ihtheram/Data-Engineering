# %% [markdown]
# # **Dataframe Questions**

# %% [markdown]
# # **1. Filter Rows**

# %% [markdown]
# Question 1: From the dataset below, filter all rows where City is "NY" and Discount_Applied is "Yes".
# ```
#    Customer_ID  Age  Gender  Purchase_Amount_USD Discount_Applied     City
# 0            1   24    Male                  253              Yes       NY
# 1            2   45  Female                  364               No       SF
# 2            3   31    Male                  540              Yes       NY
# 3            4   28  Female                  120               No  Chicago
# ```

# %%
# @title Your Answer Below {"vertical-output":true,"display-mode":"both"}
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Age": [24, 45, 31, 28],
    "Gender": ["Male", "Female", "Male", "Female"],
    "Purchase_Amount_USD": [253, 364, 540, 120],
    "Discount_Applied": ["Yes", "No", "Yes", "No"],
    "City": ["NY", "SF", "NY", "Chicago"]
}
df = pd.DataFrame(data)

# Your Answer Below

df = df[ (df["City"] == "NY") & (df["Discount_Applied"] == "Yes")]

print(df)
# Out:
#    Customer_ID  Age Gender  Purchase_Amount_USD Discount_Applied City
# 0            1   24   Male                  253              Yes   NY
# 2            3   31   Male                  540              Yes   NY

# %% [markdown]
# ---

# %% [markdown]
# # **2. Grouping and Aggregation**

# %% [markdown]
# Question 2:
# **Using the data below, calculate the average Purchase_Amount_USD for each City.**
#
# ```
#    Customer_ID City  Purchase_Amount_USD
# 0            1   NY                  253
# 1            2   SF                  364
# 2            3   LA                  540
# 3            4   NY                  120
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "City": ["NY", "SF", "LA", "NY"],
    "Purchase_Amount_USD": [253, 364, 540, 120]
}

df = pd.DataFrame(data)

print(df)

# %% [markdown]
# **Your Answer Below**

# %%
# @title
df = df.groupby("City")["Purchase_Amount_USD"].aggregate("mean", "Purchase_Amount_USD")
# or df =  df.groupby("City")["Purchase_Amount_USD"].mean()

print(df)

# %% [markdown]
# **Expected Output**
#
# ```
# City
# LA    540.0
# NY    186.5
# SF    364.0
# Name: Purchase_Amount_USD, dtype: float64
# ```

# %% [markdown]
# ---

# %% [markdown]
# # **3. Sorting**

# %% [markdown]
# Question 3:
#  **Sort the dataset below by Review_Rating in descending order.**
#
# **Expected output**
#
#
# ```
#    Customer_ID  Purchase_Amount_USD  Review_Rating
# 2            3                  540            4.8
# 0            1                  253            4.2
# 1            2                  364            3.7
# 3            4                  120            3.2
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Purchase_Amount_USD": [253, 364, 540, 120],
    "Review_Rating": [4.2, 3.7, 4.8, 3.2]
}

df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
df = df.sort_values("Review_Rating", ascending = False)

# %% [markdown]
# ---

# %% [markdown]
# # **4. Filtering and Aggregation**

# %% [markdown]
# Question 4:
#   How many customers applied a discount in "Electronics"?
#
# **Expected Output**
#
#
# ```
# 2
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4, 5],
    "Category": ["Electronics", "Furniture", "Electronics", "Clothing", "Electronics"],
    "Discount_Applied": ["Yes", "No", "Yes", "Yes", "No"]
}


df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
@title
count = len(df[ (df["Category"] == "Electronics") & (df["Discount_Applied"] == "Yes")])

# or df =  df[(df["Category"] == "Electronics") & (df["Discount_Applied"] == "Yes")].shape[0]

# %% [markdown]
# ---

# %% [markdown]
# # **5. Creating a New Column**

# %% [markdown]
# Question 5:
#  Create a new column called Age_Group that categorizes ages into <25, 25-35, and 36+.
#
# **Expected Output**
#
#
# ```
#    Customer_ID  Age Age_Group
# 0            1   24       <25
# 1            2   45       36+
# 2            3   31     25-35
# 3            4   28     25-35
#
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Age": [24, 45, 31, 28]
}

df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
# @title
df.insert(2, "Age_Group", ["<25" if x < 25 else "25-35" if 25 < x < 35 else "36+" for x in df["Age"]] )
# Solution: df["Age_Group"] = pd.cut(df["Age"], bins=[0, 25, 35, 65], labels=["<25", "25-35", "36+"])

print(df)

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
df["Age_Group"] = pd.cut(df["Age"], bins=[0, 25, 35, 65], labels=["<25", "25-35", "36+"])

# %% [markdown]
# ---

# %% [markdown]
# # **6. Find the Maximum**

# %% [markdown]
# Question 6:
#  Find the category with the highest total purchase amount.
#
# **Expected Output**
#
#
# ```
# Clothing
# ```

# %%
import pandas as pd
data = {
    "Category": ["Electronics", "Furniture", "Clothing", "Electronics", "Clothing"],
    "Purchase_Amount_USD": [253, 364, 540, 120, 200]
}
df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
# @title
max = df["Category"][df["Purchase_Amount_USD"] == df["Purchase_Amount_USD"].max()].values[0]
# or category_revenue = df.groupby("Category")["Purchase_Amount_USD"].sum()
# top_category = category_revenue.idxmax()

# %% [markdown]
# Solution:    ⚠️ Please do not open the Solution before solving

# %%
# @title
category_revenue = df.groupby("Category")["Purchase_Amount_USD"].sum()
top_category = category_revenue.idxmax()

# %% [markdown]
# ---

# %% [markdown]
# # **7. Count Occurrences**

# %% [markdown]
# Question 7:
#  Count the number of purchases made by each city.
#
# **Expected Output**
#
#
# ```
# City
# NY    2
# SF    2
# LA    1
# Name: count, dtype: int64
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4, 5],
    "City": ["NY", "SF", "LA", "NY", "SF"]
}

df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
# @title
df = df["City"].value_counts()


print(df)

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
df = df["City"].value_counts()

# %% [markdown]
# ---

# %% [markdown]
# # **8. Merging Two DataFrames**

# %% [markdown]
# Question 8:
#  Merge the two datasets below on Customer_ID.
#
# **Expected Output**
#
#
# ```
#    Customer_ID  Age  Purchase_Amount_USD
# 0            1   24                  253
# 1            2   45                  364
# 2            3   31                  540
# 3            4   28                  120
#
# ```

# %%
import pandas as pd
data1 = {
    "Customer_ID": [1, 2, 3, 4],
    "Age": [24, 45, 31, 28]
}
data2 = {
    "Customer_ID": [1, 2, 3, 4],
    "Purchase_Amount_USD": [253, 364, 540, 120]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %% [markdown]
# **Your Answer Below**

# %%
# @title
df1.insert(2, "Purchase_Amount_USD", [x for x in df2["Purchase_Amount_USD"]])
# Solution: df = pd.merge(df1, df2, on="Customer_ID")

print(df1)

# %% [markdown]
# ---

# %% [markdown]
# # **9. Dropping Rows**

# %% [markdown]
# Question 9:
#  Remove all rows where Review_Rating is below 3.0.
#
# **Expected Output**
#
#
# ```
#    Customer_ID  Review_Rating
# 0            1            4.2
# 2            3            3.7
# 3            4            3.2
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Review_Rating": [4.2, 2.8, 3.7, 3.2]
}

df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
# @title
df = df.drop(df[df["Review_Rating"] < 3.0].index)
# Solution: output = df[df["Review_Rating"] >= 3.0]

print(df)

# %% [markdown]
# ---

# %% [markdown]
# # **10. Apply Function**

# %% [markdown]
# Question 10:
#  Add a new column called Discount_Flag that is 1 if Discount_Applied is "Yes" and 0 otherwise.
#
# **Expected Output**
#
#
# ```
#    Customer_ID Discount_Applied  Discount_Flag
# 0            1              Yes              1
# 1            2               No              0
# 2            3              Yes              1
# 3            4               No              0
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Discount_Applied": ["Yes", "No", "Yes", "No"]
}
df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
# @title
df.insert(2, "Discount_Flag", [1 if x == "Yes" else 0 for x in df["Discount_Applied"]])
# Solution: df["Discount_Flag"] =  df["Discount_Applied"].apply(lambda x: 1 if x == "Yes" else 0)

print(df)

# %% [markdown]
# ---

# %% [markdown]
# # **11. Pivot Table**

# %% [markdown]
# Question 11:
#  Create a pivot table that shows the average Purchase_Amount_USD for each Category and City.
#
#  **Expected Output**
#
#
# ```
# City            LA     NY     SF
# Category
# Clothing     120.0    NaN    NaN
# Electronics    NaN  396.5    NaN
# Furniture      NaN    NaN  282.0
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4, 5],
    "Category": ["Electronics", "Furniture", "Electronics", "Clothing", "Furniture"],
    "City": ["NY", "SF", "NY", "LA", "SF"],
    "Purchase_Amount_USD": [253, 364, 540, 120, 200]
}

df = pd.DataFrame(data)
print(df)

# %% [markdown]
# **Your Answer Below**

# %%
# @title
pd.pivot_table(df, values="Purchase_Amount_USD", index=["Category"], columns=["City"], aggfunc="mean")
# Solution: output = df.pivot_table(values="Purchase_Amount_USD", index="Category", columns="City", aggfunc="mean")
# Out:
# City            LA     NY     SF
# Category
# Clothing     120.0    NaN    NaN
# Electronics    NaN  396.5    NaN
# Furniture      NaN    NaN  282.0

# %% [markdown]
# ---

# %% [markdown]
# # **12. Multi-Level Grouping**

# %% [markdown]
# Question 12:
#  Group by Category and City, and calculate both the total and average Purchase_Amount_USD for each group.
#
# **Expected Output**
#
#
# ```
#                   sum   mean
# Category    City
# Clothing    LA    120  120.0
# Electronics NY    793  396.5
# Furniture   SF    564  282.0
# ```

# %%
import pandas as pd
data = {
    "Category": ["Electronics", "Furniture", "Electronics", "Clothing", "Furniture"],
    "City": ["NY", "SF", "NY", "LA", "SF"],
    "Purchase_Amount_USD": [253, 364, 540, 120, 200]
}

df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
# @title
grouped = df.groupby(['Category', 'City'])["Purchase_Amount_USD"].aggregate(["sum", "mean"])
# Solution: df =   df.groupby(["Category", "City"])["Purchase_Amount_USD"].agg(["sum", "mean"])

print(grouped)

# %% [markdown]
# ---

# %% [markdown]
# # **13. Reshaping with Melt**

# %% [markdown]
# Question 13:
#  Reshape the dataset below using the melt function to create a long format where each row represents a City and its Purchase_Amount_USD.
#
# **Expected output**
#
#
# ```
#    Customer_ID     City  Purchase_Amount_USD
# 0            1  City_NY                  253
# 1            2  City_NY                  364
# 2            3  City_NY                  540
# 3            1  City_SF                  120
# 4            2  City_SF                  300
# 5            3  City_SF                  250
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3],
    "City_NY": [253, 364, 540],
    "City_SF": [120, 300, 250]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Customer_ID  City_NY  City_SF
# 0            1      253      120
# 1            2      364      300
# 2            3      540      250

# %% [markdown]
# **Your Answer Below**

# %%
# @title
df = df.melt(id_vars='Customer_ID', var_name = 'City', value_name = 'Purchase_Amount_USD')

print(df)
# Out:
#    Customer_ID     City  Purchase_Amount_USD
# 0            1  City_NY                  253
# 1            2  City_NY                  364
# 2            3  City_NY                  540
# 3            1  City_SF                  120
# 4            2  City_SF                  300
# 5            3  City_SF                  250

# %% [markdown]
# ---

# %% [markdown]
# # **14. Advanced Filtering**

# %% [markdown]
# Question 14 :
#  Filter customers who have a Purchase_Amount_USD greater than 300 and a Review_Rating of 4.0 or higher.
#
# **Expected output**
#
#
# ```
#    Customer_ID  Purchase_Amount_USD  Review_Rating
# 2            3                  540            4.8
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Purchase_Amount_USD": [253, 400, 540, 120],
    "Review_Rating": [4.2, 3.8, 4.8, 4.0]
}

df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
# @title
output = df[(df["Purchase_Amount_USD"] > 300) & (df["Review_Rating"] >= 4.0)]
print(output)

# %% [markdown]
# ---

# %% [markdown]
# # **15. Adding Rolling Average**

# %% [markdown]
# Question 15:
#  Add a new column called Rolling_Avg that calculates the 3-period rolling average of Purchase_Amount_USD.
#
# **Expected Output**
#
#
# ```
#    Customer_ID  Purchase_Amount_USD  Rolling_Avg
# 0            1                  253          NaN
# 1            2                  364          NaN
# 2            3                  540   385.666667
# 3            4                  120   341.333333
# 4            5                  450   370.000000
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4, 5],
    "Purchase_Amount_USD": [253, 364, 540, 120, 450]
}

df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
#@title
df["Rolling_Avg"] = df["Purchase_Amount_USD"].rolling(window = 3).mean()
print(df)

# %% [markdown]
# ---

# %% [markdown]
# # **16. Ranking**

# %% [markdown]
# Question 16:
#  Rank the customers based on Purchase_Amount_USD in descending order.
#
# **Expected Output**
#
#
# ```
#    Customer_ID  Purchase_Amount_USD  Rank
# 0            1                  253   3.0
# 1            2                  400   2.0
# 2            3                  540   1.0
# 3            4                  120   4.0
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Purchase_Amount_USD": [253, 400, 540, 120]
}

df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
# @title
df["Rank"] = df["Purchase_Amount_USD"].rank(ascending=False, method="min")
print(df)

# %% [markdown]
# ---

# %% [markdown]
# # **17. Percentage of Total**

# %% [markdown]
# Question 17:
#  Calculate the percentage of the total Purchase_Amount_USD for each row.
#
# **Expected Output**
#
#
# ```
#    Customer_ID  Purchase_Amount_USD  Percentage_of_Total
# 0            1                  253            19.268850
# 1            2                  400            30.464585
# 2            3                  540            41.127190
# 3            4                  120             9.139375
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Purchase_Amount_USD": [253, 400, 540, 120]
}
df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
# @title
df["Percentage_of_Total"] = df["Purchase_Amount_USD"] * (100 / df["Purchase_Amount_USD"].sum())
print(df)

# %% [markdown]
# Solution:    ⚠️ Please do not open the Solution before solving

# %%
# @title
df["Percentage_of_Total"] = (df["Purchase_Amount_USD"] / df["Purchase_Amount_USD"].sum()) * 100

# %% [markdown]
# ---

# %% [markdown]
# # **18. Filtering Based on String Conditions**

# %% [markdown]
# Question 18:
#  Filter all rows where the City starts with "S".
#
#  **Expected Output**
#
#
# ```
#    Customer_ID     City
# 1            2       SF
# 3            4  Seattle
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "City": ["NY", "SF", "LA", "Seattle"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Customer_ID     City
# 0            1       NY
# 1            2       SF
# 2            3       LA
# 3            4  Seattle

# %% [markdown]
# **Your Answer Below**

# %%
# @title
filtered_rows  = df[ df["City"].str.match("^S") ]
print(filtered_rows)
# Out:
#    Customer_ID     City
# 1            2       SF
# 3            4  Seattle

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
output = df[df["City"].str.startswith("S")]

# %% [markdown]
# ---

# %% [markdown]
# # **19. Cumulative Sum**

# %% [markdown]
# Question 19:
#  Add a new column called Cumulative_Sum that calculates the cumulative sum of Purchase_Amount_USD.
#
# **Expected Output**
#
#
# ```
#    Customer_ID  Purchase_Amount_USD  Cumulative_Sum
# 0            1                  253             253
# 1            2                  400             653
# 2            3                  540            1193
# 3            4                  120            1313
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Purchase_Amount_USD": [253, 400, 540, 120]
}
df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
df["Cumulative_Sum"] = df["Purchase_Amount_USD"].cumsum()
print(df)

# %% [markdown]
# Solution:    ⚠️ Please do not open the Solution before solving

# %%
# @title
df["Cumulative_Sum"] = df["Purchase_Amount_USD"].cumsum()

# %% [markdown]
# ---

# %% [markdown]
# # **20. Custom Aggregation**

# %% [markdown]
# Question 20:
#  For each City, calculate the minimum, maximum, and mean Purchase_Amount_USD.
#
#  **Expected Output**
#
#
# ```
#       min  max   mean
# City
# LA    120  120  120.0
# NY    253  540  396.5
# SF    364  450  407.0
#
# ```

# %%
import pandas as pd
data = {
    "City": ["NY", "SF", "NY", "LA", "SF"],
    "Purchase_Amount_USD": [253, 364, 540, 120, 450]
}
df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
aggregated_table = df.groupby("City")["Purchase_Amount_USD"].aggregate(['min', 'max', 'mean'])
print(aggregated_table)

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
output = df.groupby("City")["Purchase_Amount_USD"].agg(["min", "max", "mean"])

# %% [markdown]
# ---

# %% [markdown]
# # **21. Extracting Date Information**

# %% [markdown]
# Question 21:
#  Extract the year and month from the Purchase_Date column and create two new columns: Year and Month.
#
# **Expected Output**
#
#
# ```
#    Customer_ID Purchase_Date  Year  Month
# 0            1    2023-01-15  2023      1
# 1            2    2022-05-20  2022      5
# 2            3    2023-07-11  2023      7
# 3            4    2022-12-01  2022     12
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Purchase_Date": ["2023-01-15", "2022-05-20", "2023-07-11", "2022-12-01"]
}

df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
df["Year"] = df["Purchase_Date"].str[:4]
df["Month"] = df["Purchase_Date"].str[5:7]

print(df)
# Out:
#    Customer_ID Purchase_Date  Year Month
# 0            1    2023-01-15  2023    01
# 1            2    2022-05-20  2022    05
# 2            3    2023-07-11  2023    07
# 3            4    2022-12-01  2022    12

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
df["Year"] = pd.to_datetime(df["Purchase_Date"]).dt.year
df["Month"] = pd.to_datetime(df["Purchase_Date"]).dt.month

# %% [markdown]
# ---

# %% [markdown]
# # **22. Merge with Condition**

# %% [markdown]
# Question 22:
#  Merge two datasets based on Customer_ID but only include rows where Purchase_Amount_USD is greater than 300.
#
# ```
#     Customer_ID  Purchase_Amount_USD                Customer_ID     City
# 0            1                  253              0            1       NY
# 1            2                  400              1            2       SF
# 2            3                  540              2            3       LA
# 3            4                  120              3            4  Chicago
# ```

# %%
import pandas as pd
data1 = {
    "Customer_ID": [1, 2, 3, 4],
    "Purchase_Amount_USD": [253, 400, 540, 120]
}
data2 = {
    "Customer_ID": [1, 2, 3, 4],
    "City": ["NY", "SF", "LA", "Chicago"]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %% [markdown]
# **Your Answer Below**

# %%
merged_df = df1.merge(df2, on = "Customer_ID")[df1['Purchase_Amount_USD'] > 300]
print(merged_df)

# %% [markdown]
# **Expected Output**
#
#
# ```
#    Customer_ID  Purchase_Amount_USD City
# 0            2                  400   SF
# 1            3                  540   LA
# ```

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
output =  pd.merge(df1[df1["Purchase_Amount_USD"] > 300], df2, on="Customer_ID")

# %% [markdown]
# ---

# %% [markdown]
# # **23. Index Manipulation**

# %% [markdown]
# Question 23:
#  Set the Customer_ID column as the index, and then reset it back to a regular column.
#
# ```
#    Customer_ID     City
# 0            1       NY
# 1            2       SF
# 2            3       LA
# 3            4  Chicago
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "City": ["NY", "SF", "LA", "Chicago"]
}
df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
df.set_index("Customer_ID", inplace = True) # inplace=True tells pandas to modify the DataFrame directly instead of returning a new one.
df.reset_index(inplace = True)

# %% [markdown]
# **Expected Output**
#
#
# ```
#    Customer_ID     City
# 0            1       NY
# 1            2       SF
# 2            3       LA
# 3            4  Chicago
# ```

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
df.set_index("Customer_ID", inplace=True)
df.reset_index(inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# # **24. Apply Custom Function**

# %% [markdown]
# Question 24:
#  Create a new column called High_Spender that is True if Purchase_Amount_USD is greater than 500, else False.
#
# ```
#     Customer_ID  Purchase_Amount_USD
# 0            1                  253
# 1            2                  400
# 2            3                  540
# 3            4                  120
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Purchase_Amount_USD": [253, 400, 540, 120]
}
df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
df['High_Spender'] = df['Purchase_Amount_USD'].apply(lambda x : True if x > 500 else False)

print(df)

# %% [markdown]
# **Expected Output**
#
#
# ```
#    Customer_ID  Purchase_Amount_USD  High_Spender
# 0            1                  253         False
# 1            2                  400         False
# 2            3                  540          True
# 3            4                  120         False
# ```

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
df["High_Spender"] = df["Purchase_Amount_USD"].apply(lambda x: True if x > 500 else False)

# %% [markdown]
# ---

# %% [markdown]
# # **25. Resampling Time Series**

# %% [markdown]
# Question 25:
#  Resample the data to calculate the monthly total of Purchase_Amount_USD.
#
# ```
#   Purchase_Date  Purchase_Amount_USD
# 0    2023-01-15                  253
# 1    2023-01-20                  400
# 2    2023-02-10                  540
# 3    2023-03-01                  120
# ```

# %%
import pandas as pd
data = {
    "Purchase_Date": ["2023-01-15", "2023-01-20", "2023-02-10", "2023-03-01"],
    "Purchase_Amount_USD": [253, 400, 540, 120]
}
df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
df['Purchase_Date'] = pd.to_datetime(df['Purchase_Date'])
df.set_index("Purchase_Date", inplace = True)

monthly_total = df.resample("ME")["Purchase_Amount_USD"].sum() # Frequency Strings : "D" → daily, "W" → weekly, "ME" → monthly, "YE" → yearly, "h" → hourly, "15min" → 15 minutes

print(monthly_total)

# %% [markdown]
# **Expected Output**
#
#
# ```
# Purchase_Date
# 2023-01-31    653
# 2023-02-28    540
# 2023-03-31    120
# Freq: ME, Name: Purchase_Amount_USD, dtype: int64
# ```

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
df["Purchase_Date"] = pd.to_datetime(df["Purchase_Date"])
df.set_index("Purchase_Date", inplace=True)
monthly_total = df.resample("M")["Purchase_Amount_USD"].sum()

# %% [markdown]
# ---

# %% [markdown]
# # **26. Filtering with Multiple Conditions**

# %% [markdown]
# Question 26:
#  Filter all rows where Category is either "Electronics" or "Furniture" and City is not "NY".
# ```
#     Customer_ID     Category     City
# 0            1  Electronics       NY
# 1            2    Furniture       SF
# 2            3     Clothing       LA
# 3            4  Electronics  Chicago

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Category": ["Electronics", "Furniture", "Clothing", "Electronics"],
    "City": ["NY", "SF", "LA", "Chicago"]
}
df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
df = df[ (df['City'] != 'NY') & (df['Category'] == 'Electronics') | (df['Category'] == 'Furniture') ]
print(df)

# %% [markdown]
# **Expected Output**
#
#
# ```
#    Customer_ID     Category     City
# 1            2    Furniture       SF
# 3            4  Electronics  Chicago
# ```

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
output =  df[(df["Category"].isin(["Electronics", "Furniture"])) & (df["City"] != "NY")]

# %% [markdown]
# ---

# %% [markdown]
# # **27. Multi-Indexing**

# %% [markdown]
# Question 27:
#  Create a multi-index using City and Category and calculate the sum of Purchase_Amount_USD for each combination.
#
#  ```
#    City     Category  Purchase_Amount_USD
# 0   NY  Electronics                  253
# 1   SF    Furniture                  364
# 2   NY     Clothing                  540
# 3   LA  Electronics                  120
#  ```

# %%
import pandas as pd
data = {
    "City": ["NY", "SF", "NY", "LA"],
    "Category": ["Electronics", "Furniture", "Clothing", "Electronics"],
    "Purchase_Amount_USD": [253, 364, 540, 120]
}
df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
df.set_index(['City', 'Category'], inplace = True)
sum = df.groupby(['City', 'Category']).aggregate('sum')

# %% [markdown]
# **Expected Output**
#
#
# ```
#                   Purchase_Amount_USD
# City Category
# LA   Electronics                  120
# NY   Clothing                     540
#      Electronics                  253
# SF   Furniture                    364
# ```

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
df.set_index(["City", "Category"], inplace=True)
s_multi_index_sum = df.groupby(["City", "Category"]).sum()

# %% [markdown]
# ---

# %% [markdown]
# # **28. Handling Missing Data**

# %% [markdown]
# Question 28:
#  Fill missing values in the Review_Rating column with the average rating.
#
#  ```
#     Customer_ID  Review_Rating
# 0            1            4.2
# 1            2            NaN
# 2            3            3.7
# 3            4            NaN
#  ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Review_Rating": [4.2, None, 3.7, None]
}
df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
df["Review_Rating"] = df["Review_Rating"].fillna(df['Review_Rating'].mean())
# df.fillna({"Review_Rating" : (df['Review_Rating'].mean()) }, inplace=True)

print(df)

# %% [markdown]
# **Expected Output**
#
#
# ```
#    Customer_ID  Review_Rating
# 0            1           4.20
# 1            2           3.95
# 2            3           3.70
# 3            4           3.95
# ```

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
# df["Review_Rating"] = df["Review_Rating"].fillna(df['Review_Rating'].mean())
# OR
# df.fillna({"Review_Rating" : (df['Review_Rating'].mean()) }, inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# # **29. Duplicates Handling**

# %% [markdown]
# Question 29:
#  Remove duplicate rows based on the Category column, keeping only the first occurrence.
# ```
#     Customer_ID     Category
# 0            1  Electronics
# 1            2    Furniture
# 2            3  Electronics
# 3            4     Clothing
# ```

# %%
import pandas as pd
data = {
    "Customer_ID": [1, 2, 3, 4],
    "Category": ["Electronics", "Furniture", "Electronics", "Clothing"]
}
df = pd.DataFrame(data)

# %% [markdown]
# **Your Answer Below**

# %%
df.drop_duplicates(subset="Category", keep="first", inplace=True)

# %% [markdown]
# **Expected Output**
#
#
# ```
#    Customer_ID     Category
# 0            1  Electronics
# 1            2    Furniture
# 3            4     Clothing
# ```

# %% [markdown]
# **Solution:    ⚠️ Please do not open the Solution before solving**

# %%
# @title
output = df.drop_duplicates(subset="Category", keep="first")
print(output)

# %% [markdown]
# **END OF QUESTIONS**
